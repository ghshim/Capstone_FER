# %%
import cv2
import matplotlib.pyplot as plt
import preprocess

# %%
image = cv2.imread('face.png')
plt.imshow(image)

# %%
new = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
new.shape
# Out:
# (743, 1000)

# %%
new = cv2.cvtColor(new, cv2.COLOR_GRAY2BGR)
plt.imshow(new)

# %%
landmark_face = preprocess.reduced_face_mesh(new)
landmark_face
# Out:
# array([[[228, 228, 228],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        [[229, 229, 229],
#         [229, 229, 229],
#         [229, 229, 229],
#         ...,
#         [238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238]],
#
#        ...,
#
#        [[223, 223, 223],
#         [223, 223, 223],
#         [222, 222, 222],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[222, 222, 222],
#         [222, 222, 222],
#         [222, 222, 222],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[221, 221, 221],
#         [221, 221, 221],
#         [222, 222, 222],
# ...

# %%
plt.imshow(landmark_face)
